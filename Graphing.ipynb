# %% [markdown]
# <a href="https://colab.research.google.com/github/KingNook/2048/blob/main/Graphing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/6th Oct - 28th Oct AirGradient data.csv')

# %%
df.head()
# Out:
#    Location ID Location Name  Location Group Location Type  \
# 0        80169  34b7dad311b4             NaN       Outdoor
# 1        80169  34b7dad311b4             NaN       Outdoor
# 2        80169  34b7dad311b4             NaN       Outdoor
# 3        80169  34b7dad311b4             NaN       Outdoor
# 4        80169  34b7dad311b4             NaN       Outdoor
#
#                   Sensor ID  Place Open      Local Date/Time  \
# 0  airgradient:34b7dad311b4        True  2025-10-28 14:05:00
# 1  airgradient:34b7dad311b4        True  2025-10-28 14:00:00
# 2  airgradient:34b7dad311b4        True  2025-10-28 13:55:00
# 3  airgradient:34b7dad311b4        True  2025-10-28 13:50:00
# 4  airgradient:34b7dad311b4        True  2025-10-28 13:45:00
#
#               UTC Date/Time  # of aggregated records  PM2.5 (μg/m³) raw  ...  \
# 0  2025-10-28T14:05:00.000Z                        5                0.0  ...
# 1  2025-10-28T14:00:00.000Z                        4                0.0  ...
# ...

# %%
df_clean = df[['Local Date/Time'],
